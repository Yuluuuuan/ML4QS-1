# %%
from Chapter2.CreateDataset import CreateDataset
import pandas as pd
import matplotlib.pyplot as plt
import os
import copy
from util.VisualizeDataset import VisualizeDataset
from util import util

# %%
rawdatapath = "data/raw/"
outputpath = "data/intermediate/"
givenpath = "data/given/"

if not os.path.exists(outputpath):
    print("Empty path, so creating..." + outputpath + "...done!")
    os.makedirs(outputpath)

# %%
accraw = pd.read_csv(rawdatapath + "Accelerometer.csv")
timecol = "Time (s)"
accfeatures = list()
for col in accraw:
    if (col != timecol) and \
    (col != "Absolute acceleration (m/s^2)"):
        accfeatures.append(col)
accfeatures
# Out:
# ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)']

# %%
accraw
# Out:
#           Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0         0.018694               -1.977070                7.584650
# 1         0.021144               -2.020140                7.582257
# 2         0.023594               -2.003391                7.591828
# 3         0.026045               -2.008176                7.579864
# 4         0.028495               -1.993819                7.591828
# ...            ...                     ...                     ...
# 124856  300.012150               -2.254936                7.548757
# 124857  300.014552               -2.257329                7.560721
# 124858  300.016956               -2.235794                7.536793
# 124859  300.019358               -2.245365                7.541579
# 124860  300.021760               -2.259722                7.541579
#
#         Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                     6.073283                       9.915669
# 1                     6.054141                       9.910812
# 2                     6.054141                       9.914739
# 3                     6.056533                       9.908012
# 4                     6.020641                       9.892385
# ...                        ...                            ...
# 124856                5.733502                       9.743794
# 124857                5.735895                       9.755026
# 124858                5.757431                       9.744231
# 124859                5.764609                       9.754373
# 124860                5.769394                       9.760516
#
# [124861 rows x 5 columns]

# %%
accgiven = pd.read_csv(givenpath + "accelerometer_phone.csv")
timecol = "Time (s)"
accfeatures_given = list()
for col in accgiven:
    if (col != timecol) and \
    (col != "Absolute acceleration (m/s^2)"):
        accfeatures_given.append(col)
accfeatures_given
# Out:
# ['sensor_type', 'device_type', 'timestamps', 'x', 'y', 'z']

# %%
accgiven
# Out:
#            sensor_type device_type           timestamps      x      y      z
# 0        accelerometer  smartphone  1454956105656222395 -0.087  0.181  9.621
# 1        accelerometer  smartphone  1454956105660105781 -0.069  0.153  9.663
# 2        accelerometer  smartphone  1454956105667091406 -0.073  0.156  9.647
# 3        accelerometer  smartphone  1454956105670696615 -0.070  0.184  9.623
# 4        accelerometer  smartphone  1454956105675807552 -0.059  0.171  9.625
# ...                ...         ...                  ...    ...    ...    ...
# 1604601  accelerometer  smartphone  1454964064977354323 -0.166  0.178  9.628
# 1604602  accelerometer  smartphone  1454964064982928229 -0.174  0.183  9.643
# 1604603  accelerometer  smartphone  1454964064987681354 -0.174  0.183  9.643
# 1604604  accelerometer  smartphone  1454964064992564896 -0.154  0.177  9.666
# 1604605  accelerometer  smartphone  1454964064996744531 -0.159  0.203  9.629
#
# [1604606 rows x 6 columns]

# %%
acctime = pd.read_csv(rawdatapath + "Accelerometer_time.csv")
acctime
# Out:
#    event  experiment time   system time                   system time text
# 0  START         0.000000  1.622380e+09  2021-05-30 21:08:32.654 UTC+08:00
# 1  PAUSE       300.027308  1.622380e+09  2021-05-30 21:13:32.681 UTC+08:00

# %%
acctime["system time"][0]
# Out:
# 1622380112.654

# %%
accraw["Time (s)"] = accraw["Time (s)"] + acctime["system time"][0]

# %%
accraw
# Out:
#             Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       1.622380e+09               -1.977070                7.584650
# 1       1.622380e+09               -2.020140                7.582257
# 2       1.622380e+09               -2.003391                7.591828
# 3       1.622380e+09               -2.008176                7.579864
# 4       1.622380e+09               -1.993819                7.591828
# ...              ...                     ...                     ...
# 124856  1.622380e+09               -2.254936                7.548757
# 124857  1.622380e+09               -2.257329                7.560721
# 124858  1.622380e+09               -2.235794                7.536793
# 124859  1.622380e+09               -2.245365                7.541579
# 124860  1.622380e+09               -2.259722                7.541579
#
#         Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                     6.073283                       9.915669
# 1                     6.054141                       9.910812
# 2                     6.054141                       9.914739
# 3                     6.056533                       9.908012
# 4                     6.020641                       9.892385
# ...                        ...                            ...
# 124856                5.733502                       9.743794
# 124857                5.735895                       9.755026
# 124858                5.757431                       9.744231
# 124859                5.764609                       9.754373
# 124860                5.769394                       9.760516
#
# [124861 rows x 5 columns]

# %%
accraw.to_csv("test.csv")

# %%
granularities = [60000, 250]
datasets = []

# %%
for g in granularities:
    
    Dataset = CreateDataset(rawdatapath, g)
    
    Dataset.add_numerical_dataset(accraw, timecol, accfeatures, "avg", "acc_")
    
    dataset = Dataset.data_table
    print(dataset)
#     Dataviz = VisualizeDataset()
    
#     Dataviz.plot_dataset_boxplot(dataset, ['acc_Acceleration x (m/s^2)', 'acc_Acceleration y (m/s^2)', 'acc_Acceleration z (m/s^2)'])
# Out:
# Reading data from             Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       1.622380e+09               -1.977070                7.584650
# 1       1.622380e+09               -2.020140                7.582257
# 2       1.622380e+09               -2.003391                7.591828
# 3       1.622380e+09               -2.008176                7.579864
# 4       1.622380e+09               -1.993819                7.591828
# ...              ...                     ...                     ...
# 124856  1.622380e+09               -2.254936                7.548757
# 124857  1.622380e+09               -2.257329                7.560721
# 124858  1.622380e+09               -2.235794                7.536793
# 124859  1.622380e+09               -2.245365                7.541579
# 124860  1.622380e+09               -2.259722                7.541579
#
#         Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                     6.073283                       9.915669
# 1                     6.054141                       9.910812
# 2                     6.054141                       9.914739
# 3                     6.056533                       9.908012
# 4                     6.020641                       9.892385
# ...                        ...                            ...
# 124856                5.733502                       9.743794
# 124857                5.735895                       9.755026
# 124858                5.757431                       9.744231
# 124859                5.764609                       9.754373
# 124860                5.769394                       9.760516
#
# [124861 rows x 5 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-383d12ab9131> in <module>
#       3     Dataset = CreateDataset(rawdatapath, g)
#       4
# ----> 5     Dataset.add_numerical_dataset(accraw, timecol, accfeatures, "avg", "acc_")
#       6
#       7     dataset = Dataset.data_table
#
# ~/Documents/University/Year1P6/MLFQS/Code/ML4QS/assignment01/Chapter2/CreateDataset.py in add_numerical_dataset(self, file, timestamp_col, value_cols, aggregation, prefix)
#      43     def add_numerical_dataset(self, file, timestamp_col, value_cols, aggregation='avg', prefix=''):
#      44         print(f'Reading data from {file}')
# ---> 45         dataset = pd.read_csv(self.base_dir + file, skipinitialspace=True)
#      46
#      47         # Convert timestamps to dates
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     781                 self = self.fillna(fill_value)
#     782
# --> 783             new_data = dispatch_to_series(self, other, op, str_rep)
#     784             return self._construct_result(new_data)
#     785
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     379         # Get the appropriate array-op to apply to each block's values.
#     380         array_op = get_array_op(func, str_rep=str_rep)
# --> 381         bm = left._data.apply(array_op, right=right)
#     382         return type(left)(bm)
#     383
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     147
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#     151         result = masked_arith_op(left, right, op)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     109         b_value = getattr(b, "values", b)
#     110
# --> 111         result = ne.evaluate(
#     112             f"a_value {op_str} b_value",
#     113             local_dict={"a_value": a_value, "b_value": b_value},
#
# ~/anaconda3/lib/python3.8/site-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     819
#     820     # Create a signature
# --> 821     signature = [(name, getType(arg)) for (name, arg) in
#     822                  zip(names, arguments)]
#     823
#
# ~/anaconda3/lib/python3.8/site-packages/numexpr/necompiler.py in <listcomp>(.0)
#     819
#     820     # Create a signature
# --> 821     signature = [(name, getType(arg)) for (name, arg) in
#     822                  zip(names, arguments)]
#     823
#
# ~/anaconda3/lib/python3.8/site-packages/numexpr/necompiler.py in getType(a)
#     701     if kind == 'S':
#     702         return bytes
# --> 703     raise ValueError("unknown type %s" % a.dtype.name)
#     704
#     705
#
# ValueError: unknown type str288

# %%
dataset
# Out:
#            acc_Acceleration x (m/s^2) acc_Acceleration y (m/s^2)  \
# 1970-01-01                   -1.65954                    7.35627
#
#            acc_Acceleration z (m/s^2)
# 1970-01-01                     6.1556
