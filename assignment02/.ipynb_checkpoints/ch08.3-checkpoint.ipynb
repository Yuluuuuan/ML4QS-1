# %%
from util.VisualizeDataset import VisualizeDataset
from Chapter7.PrepareDatasetForLearning import PrepareDatasetForLearning
from Chapter7.Evaluation import RegressionEvaluation
from Chapter8.LearningAlgorithmsTemporal import TemporalClassificationAlgorithms
from Chapter8.LearningAlgorithmsTemporal import TemporalRegressionAlgorithms
from statsmodels.tsa.stattools import adfuller
from pandas.plotting import autocorrelation_plot
import pandas as pd
import os
import copy
from util import util
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
plt.rcParams["figure.figsize"] = [15,10]

# %%
rawdatapth = "data/result-given/"
outputpth = "data/intermediate/"

if not os.path.exists(outputpth):
    print("Empty path, so creating..." + outputpth + "...done!")
    os.makedirs(outputpth)

# %%
dataset = pd.read_csv(rawdatapth + "chapter5_result.csv", index_col=0)
dataset.index = pd.to_datetime(dataset.index)
dataset
# Out:
#                             acc_phone_x  acc_phone_y  acc_phone_z  \
# 2016-02-08 18:28:25.656222    -0.090433     0.164264     9.631744
# 2016-02-08 18:28:28.406222    -0.088630     0.170400     9.628089
# 2016-02-08 18:28:31.156222    -0.084584     0.171914     9.620668
# 2016-02-08 18:28:33.906222    -0.081381     0.170345     9.634230
# 2016-02-08 18:28:36.656222    -0.097313     0.136100     9.623921
# ...                                 ...          ...          ...
# 2016-02-08 20:40:53.156222    -0.163787     0.183251     9.611648
# 2016-02-08 20:40:55.906222    -0.163480     0.184232     9.614230
# 2016-02-08 20:40:58.656222    -0.164780     0.184331     9.615484
# 2016-02-08 20:41:01.406222    -0.162506     0.185287     9.608581
# 2016-02-08 20:41:04.156222    -0.162810     0.185584     9.611845
#
#                             acc_watch_x  acc_watch_y  acc_watch_z  \
# 2016-02-08 18:28:25.656222     9.550840     0.197679     1.513430
# 2016-02-08 18:28:28.406222     9.551315     0.197073     1.505779
# 2016-02-08 18:28:31.156222     9.552778     0.194151     1.509347
# 2016-02-08 18:28:33.906222     9.546574     0.200030     1.507089
# 2016-02-08 18:28:36.656222     9.545983     0.197746     1.516108
# ...                                 ...          ...          ...
# 2016-02-08 20:40:53.156222    -5.261667    -5.561800     7.313867
# 2016-02-08 20:40:55.906222    -5.261667    -5.561800     7.313867
# 2016-02-08 20:40:58.656222    -5.261667    -5.561800     7.313867
# 2016-02-08 20:41:01.406222    -5.261667    -5.561800     7.313867
# 2016-02-08 20:41:04.156222    -5.261667    -5.561800     7.313867
#
#                             gyr_phone_x  gyr_phone_y  gyr_phone_z  \
# 2016-02-08 18:28:25.656222    -0.008810     0.018548    -0.001514
# 2016-02-08 18:28:28.406222    -0.008870     0.018457    -0.000912
# 2016-02-08 18:28:31.156222    -0.008438     0.018855     0.000159
# 2016-02-08 18:28:33.906222    -0.008650     0.018903    -0.003626
# 2016-02-08 18:28:36.656222    -0.011363     0.015230    -0.023521
# ...                                 ...          ...          ...
# 2016-02-08 20:40:53.156222    -0.008054     0.020805     0.001829
# 2016-02-08 20:40:55.906222    -0.008538     0.021053     0.001998
# 2016-02-08 20:40:58.656222    -0.008474     0.021411     0.002339
# 2016-02-08 20:41:01.406222    -0.008452     0.021322     0.002050
Hz_ws_40  \
# 2016-02-08 18:28:25.656222                            NaN
# 2016-02-08 18:28:28.406222                            NaN
# 2016-02-08 18:28:31.156222                            NaN
# 2016-02-08 18:28:33.906222                            NaN
# 2016-02-08 18:28:36.656222                   3.274394e-01
# ...                                                   ...
# 2016-02-08 20:40:53.156222                   1.517009e-12
# 2016-02-08 20:40:55.906222                   1.517009e-12
# 2016-02-08 20:40:58.656222                   1.517009e-12
# 2016-02-08 20:41:01.406222                   1.517009e-12
# 2016-02-08 20:41:04.156222                   1.517009e-12
#
#                             mag_watch_z_freq_2.0_Hz_ws_40  cluster
# 2016-02-08 18:28:25.656222                            NaN        2
# 2016-02-08 18:28:28.406222                            NaN        2
# 2016-02-08 18:28:31.156222                            NaN        2
# 2016-02-08 18:28:33.906222                            NaN        2
# 2016-02-08 18:28:36.656222                   3.076108e-01        2
# ...                                                   ...      ...
# 2016-02-08 20:40:53.156222                  -1.524114e-12        2
# 2016-02-08 20:40:55.906222                  -1.524114e-12        2
# 2016-02-08 20:40:58.656222                  -1.524114e-12        2
# 2016-02-08 20:41:01.406222                  -1.524114e-12        2
# 2016-02-08 20:41:04.156222                  -1.524114e-12        2
#
# [2895 rows x 542 columns]

# %%
dataset.index = pd.to_datetime(dataset.index)
dataset.columns
# Out:
# Index(['acc_phone_x', 'acc_phone_y', 'acc_phone_z', 'acc_watch_x',
#        'acc_watch_y', 'acc_watch_z', 'gyr_phone_x', 'gyr_phone_y',
#        'gyr_phone_z', 'gyr_watch_x',
#        ...
#        'mag_watch_z_freq_1.2_Hz_ws_40', 'mag_watch_z_freq_1.3_Hz_ws_40',
#        'mag_watch_z_freq_1.4_Hz_ws_40', 'mag_watch_z_freq_1.5_Hz_ws_40',
#        'mag_watch_z_freq_1.6_Hz_ws_40', 'mag_watch_z_freq_1.7_Hz_ws_40',
#        'mag_watch_z_freq_1.8_Hz_ws_40', 'mag_watch_z_freq_1.9_Hz_ws_40',
#        'mag_watch_z_freq_2.0_Hz_ws_40', 'cluster'],
#       dtype='object', length=542)

# %%
DataViz = VisualizeDataset()
prepare = PrepareDatasetForLearning()

# %%
Xtrain, Xtest, ytrain, ytest = prepare.split_single_dataset_regression_by_time(dataset, 'hr_watch_rate', '2016-02-08 18:29:56', \
                                                                                   '2016-02-08 19:34:07', '2016-02-08 20:07:50')

# %%
print('Training set length is: ', len(Xtrain.index))
print('Test set length is: ', len(Xtest.index))
# Out:
# Training set length is:  1401
# Test set length is:  736

# %%
basicfeatures = ['acc_phone_x','acc_phone_y','acc_phone_z','acc_watch_x','acc_watch_y','acc_watch_z','gyr_phone_x','gyr_phone_y','gyr_phone_z','gyr_watch_x','gyr_watch_y','gyr_watch_z',
                  'labelOnTable','labelSitting','labelWashingHands','labelWalking','labelStanding','labelDriving','labelEating','labelRunning',
                  'light_phone_lux','mag_phone_x','mag_phone_y','mag_phone_z','mag_watch_x','mag_watch_y','mag_watch_z','press_phone_pressure']
pcafeatures = ['pca_1','pca_2','pca_3','pca_4','pca_5','pca_6','pca_7']
timefeatures = [name for name in dataset.columns if ('temp_' in name and not 'hr_watch' in name)]
freqfeatures = [name for name in dataset.columns if (('_freq' in name) or ('_pse' in name))]

# %%
print('#basic features: ', len(basicfeatures))
print('#PCA features: ', len(pcafeatures))
print('#time features: ', len(timefeatures))
print('#frequency features: ', len(freqfeatures))
# Out:
# #basic features:  28
# #PCA features:  7
# #time features:  71
# #frequency features:  432

# %%
clusterfeatures = ['cluster']
print('#cluster features: ', len(clusterfeatures))
# Out:
# #cluster features:  1

# %%
featuresch03 = list(set().union(basicfeatures, pcafeatures))
featuresch04 = list(set().union(basicfeatures, pcafeatures, timefeatures, freqfeatures))
featuresch05 = list(set().union(basicfeatures, pcafeatures, timefeatures, freqfeatures, clusterfeatures))

# %%
selectedfeatures = ['temp_pattern_labelOnTable','labelOnTable', 'temp_pattern_labelOnTable(b)labelOnTable', 'cluster',
                     'pca_1_temp_mean_ws_120','pca_2_temp_mean_ws_120','pca_2','acc_watch_y_temp_mean_ws_120','gyr_watch_y_pse',
                     'gyr_watch_x_pse']
possiblefeatures = [basicfeatures, featuresch03, featuresch04, featuresch05, selectedfeatures]
featurenames = ['initial set', 'Chapter 3', 'Chapter 4', 'Chapter 5', 'Selected features']

# %%
dftest = adfuller(dataset['hr_watch_rate'], autolag='AIC')

plt.Figure(); autocorrelation_plot(dataset['hr_watch_rate'])
DataViz.save(plt)
plt.show()
# Out:
# Figure saved to figures\figure_1.png

# %%
possiblefeatures = [basicfeatures]
featurenames = ["basic_features"]

selXtrain = Xtrain[possiblefeatures[0]]
selXtest = Xtest[possiblefeatures[0]]

columns = ['self.acc_watch_x', 'self.acc_watch_y', 'self.hr_watch_rate']
equations = ['self.hr_watch_rate * self.acc_watch_x', 'self.b * self.hr_watch_rate', 'self.b * self.acc_watch_y']
targets = ['self.hr_watch_rate']
parameters = ['self.b']

ytrainframe = ytrain.to_frame(name='hr_watch_rate')
ytestframe = ytest.to_frame(name='hr_watch_rate')

# %%
learner = TemporalRegressionAlgorithms()

outputsets1 = learner.dynamical_systems_model_nsga_2(selXtrain, ytrainframe, selXtest, ytestframe, columns, equations, targets, parameters)

# %%
DataViz.plot_numerical_prediction_versus_real_dynsys_mo(selXtrain.index, 
ytrainframe, selXtest.index, ytestframe, outputsets1, 0, 'hr_watch_rate')
# Out:
# Figure saved to figures\figure_2.png

# %%
# second results with larger dataset
Xtrain, Xtest, ytrain, ytest = prepare.split_single_dataset_regression(copy.deepcopy(dataset), ['hr_watch_rate'], 0.9, filter=False, temporal=True)

# %%
columns = ['self.acc_watch_x', 'self.acc_watch_y', 'self.hr_watch_rate']
equations = ['self.hr_watch_rate * self.acc_watch_x', 'self.b * self.hr_watch_rate', 'self.b * self.acc_watch_y']
targets = ['self.hr_watch_rate']
parameters = ['self.b']

learner = TemporalRegressionAlgorithms()

# %%
outputsets2 = learner.dynamical_systems_model_nsga_2(Xtrain, ytrain, Xtest, ytest, columns, equations, targets, parameters)

# %%
DataViz.plot_numerical_prediction_versus_real_dynsys_mo(Xtrain.index, ytrain, Xtest.index, ytest, outputsets2, 0, 'hr_watch_rate')
# Out:
# Figure saved to figures\figure_2.png
