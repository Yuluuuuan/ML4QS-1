# %% [markdown]
# # CH.03 - 5.9.2.2

# %%
from Chapter5.DistanceMetrics import InstanceDistanceMetrics
from Chapter5.DistanceMetrics import PersonDistanceMetricsNoOrdering
from Chapter5.DistanceMetrics import PersonDistanceMetricsOrdering
from Chapter5.Clustering import NonHierarchicalClustering
from Chapter5.Clustering import HierarchicalClustering
import util.util as util
from util.VisualizeDataset import VisualizeDataset

import sys
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import argparse

# %%
DATA_PATH = Path('./data/')
DATASET_FNAME = 'raw/Accelerometer.csv'
RESULT_FNAME = 'intermediate/chapter5_result2.csv'

# %%
dataset = pd.read_csv(DATA_PATH / DATASET_FNAME, index_col=0)
dataset.index = pd.to_datetime(dataset.index.astype(int))

# %%
DataViz = VisualizeDataset()

clusteringNH = NonHierarchicalClustering()
clusteringH = HierarchicalClustering()

# %% [markdown]
# ## Kmediods

# %%
k_values = range(2, 10)
silhouette_values = []

for k in k_values:
    print(f'k = {k}')
    dataset_cluster = clusteringNH.k_medoids_over_instances(copy.deepcopy(
        dataset), ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)'], 
                                                            k, 'default', 20, n_inits=10)
    silhouette_score = dataset_cluster['silhouette'].mean()
    print(f'silhouette = {silhouette_score}')
    silhouette_values.append(silhouette_score)
# Out:
# k = 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-84f3001163fe> in <module>
#       4 for k in k_values:
#       5     print(f'k = {k}')
# ----> 6     dataset_cluster = clusteringNH.k_medoids_over_instances(copy.deepcopy(
#       7         dataset), ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)'],
#       8                                                             k, 'default', 20, n_inits=400)
#
# ~/Downloads/ML4QS/assignment01/Chapter5/Clustering.py in k_medoids_over_instances(self, dataset, cols, k, distance_metric, max_iters, n_inits, p)
#     171         if distance_metric == 'default':
#     172             km = pyclust.KMedoids(n_clusters=k, n_trials=n_inits)
# --> 173             km.fit(temp_dataset.values)
#     174             cluster_assignment = km.labels_
#     175
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/pyclust/_kmedoids.py in fit(self, X)
#     132         """
#     133         self.centers_, self.labels_, self.sse_arr_, self.n_iter_ = \
# --> 134               _kmedoids(X, self.n_clusters, self.distance, self.max_iter, self.n_trials, self.tol, self.rng)
#     135
#     136
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/pyclust/_kmedoids.py in _kmedoids(X, n_clusters, distance, max_iter, n_trials, tol, rng)
#      60     for i in range(n_trials):
#      61         centers, labels, sse_tot, sse_arr, n_iter  = \
# ---> 62                _kmedoids_run(X, n_clusters, distance, max_iter, tol, rng)
#      63         if i==0:
#      64             sse_tot_best = sse_tot
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/pyclust/_kmedoids.py in _kmedoids_run(X, n_clusters, distance, max_iter, tol, rng)
#      40     for it in range(1,max_iter):
#      41         membs = kmeans._assign_clusters(X, centers)
# ---> 42         centers,sse_arr = _update_centers(X, membs, n_clusters, distance)
#      43         sse_total = np.sum(sse_arr)
#      44         if np.abs(sse_total - sse_last) < tol:
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/pyclust/_kmedoids.py in _update_centers(X, membs, n_clusters, distance)
#      20         dist = np.empty(shape=memb_ids.shape[0], dtype=float)
#      21         for i,x in enumerate(X_clust):
# ---> 22            dist[i] = np.sum(scipy.spatial.distance.cdist(X_clust, np.array([x]), distance))
#      23
#      24         inx_min = np.argmin(dist)
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/scipy/spatial/distance.py in cdist(XA, XB, metric, *args, **kwargs)
#    2798         metric_name = _METRIC_ALIAS.get(mstr, None)
#    2799         if metric_name is not None:
# -> 2800             XA, XB, typ, kwargs = _validate_cdist_input(XA, XB, mA, mB, n,
#    2801                                                         metric_name, **kwargs)
#    2802
#
# /Applications/anaconda3/envs/myenv/lib/python3.9/site-packages/scipy/spatial/distance.py in _validate_cdist_input(XA, XB, mA, mB, n, metric_name, **kwargs)
#     249
#     250         # validate kwargs
# --> 251         _validate_kwargs = _METRICS[metric_name].validator
#     252         if _validate_kwargs:
#     253             kwargs = _validate_kwargs(np.vstack([XA, XB]), mA + mB, n, **kwargs)
#
# KeyboardInterrupt:

# %%
DataViz.plot_xy(x=[k_values], y=[silhouette_values], xlabel='k', ylabel='silhouette score',
                ylim=[0, 1], line_styles=['b-'])

k = k_values[np.argmax(silhouette_values)]
print(f'Highest K-Medoids silhouette score: k = {k}')

dataset_kmed = clusteringNH.k_medoids_over_instances(copy.deepcopy(dataset), 
                                                     ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)'], 
                                                     k, 'default', 20, n_inits=50)
DataViz.plot_clusters_3d(dataset_kmed, ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)'], 'cluster', ['label'])
DataViz.plot_silhouette(dataset_kmed, 'cluster', 'silhouette')
util.print_latex_statistics_clusters(dataset_kmed, 'cluster', 
                                    ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)'], 'label')
