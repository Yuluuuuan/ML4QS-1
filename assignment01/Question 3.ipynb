# %%
from util.VisualizeDataset import VisualizeDataset
from Chapter3.OutlierDetection import DistributionBasedOutlierDetection
from Chapter3.OutlierDetection import DistanceBasedOutlierDetection
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
plt.rcParams["figure.figsize"] = [15,10]

# %%
rawdatapth = "data/result-given/"
outputpth = "data/intermediate/"

if not os.path.exists(outputpth):
    print("Empty path, so creating..." + outputpth + "...done!")
    os.makedirs(outputpth)

# %%
dataset = pd.read_csv(rawdatapth + "chapter2_result.csv", index_col=0, nrows=10000)
dataset.index = pd.to_datetime(dataset.index)
dataset
# Out:
#                                acc_phone_x  acc_phone_y  acc_phone_z  \
# 2016-02-08 18:28:25.656222395    -0.090431     0.164098     9.631765
# 2016-02-08 18:28:25.906222395    -0.097600     0.167640     9.631740
# 2016-02-08 18:28:26.156222395    -0.089120     0.167520     9.637300
# 2016-02-08 18:28:26.406222395    -0.090135     0.166019     9.632538
# 2016-02-08 18:28:26.656222395    -0.090608     0.167686     9.630078
# ...                                    ...          ...          ...
# 2016-02-08 19:10:04.406222395    -1.109471   -11.582451     0.009098
# 2016-02-08 19:10:04.656222395     1.229520   -10.174580    -2.400820
# 2016-02-08 19:10:04.906222395    -1.413440    -9.773780     1.805340
# 2016-02-08 19:10:05.156222395     0.781360    -9.936880    -2.036180
# 2016-02-08 19:10:05.406222395    -0.870784    -9.287627    -1.140843
#
#                                acc_watch_x  acc_watch_y  acc_watch_z  \
# 2016-02-08 18:28:25.656222395     9.550844     0.197689     1.513422
# 2016-02-08 18:28:25.906222395     9.552667     0.189271     1.511000
# 2016-02-08 18:28:26.156222395     9.549745     0.194588     1.517431
# 2016-02-08 18:28:26.406222395     9.552022     0.200000     1.498267
# 2016-02-08 18:28:26.656222395     9.550375     0.200771     1.504312
# ...                                    ...          ...          ...
# 2016-02-08 19:10:04.406222395     5.644682    -5.408523    -1.288909
# 2016-02-08 19:10:04.656222395     6.878048    -8.971071    -2.271476
# 2016-02-08 19:10:04.906222395     4.834951    -5.434000    -3.632756
# 2016-02-08 19:10:05.156222395     5.740911    -8.554556    -4.224333
# 2016-02-08 19:10:05.406222395     6.091220    -5.396902    -3.049171
#
#                                gyr_phone_x  gyr_phone_y  gyr_phone_z  \
# 2016-02-08 18:28:25.656222395    -0.008824     0.018529    -0.001647
# 2016-02-08 18:28:25.906222395    -0.008800     0.018540    -0.001540
# 2016-02-08 18:28:26.156222395    -0.008880     0.018340    -0.002420
# 2016-02-08 18:28:26.406222395    -0.008962     0.018288    -0.002038
# 2016-02-08 18:28:26.656222395    -0.008760     0.018800    -0.002260
# ...                                    ...          ...          ...
# 2016-02-08 19:10:04.406222395     0.025118     0.415373    -0.140627
# 2016-02-08 19:10:04.656222395     1.680800    -0.157720     1.258660
# 2016-02-08 19:10:04.906222395    -0.482500    -0.477660     0.064360
# 2016-02-08 19:10:05.156222395    -0.748040     0.312520    -0.786100
# 2016-02-08 19:10:05.406222395    -0.739962     0.283442    -0.276654
#
#                                gyr_watch_x  ...  labelEating  labelRunning  \
outliercols = ["acc_phone_x", "light_phone_lux"]

OutlierDistr = DistributionBasedOutlierDetection()
OutlierDist = DistanceBasedOutlierDetection()

# %%
DataViz = VisualizeDataset()

# %% [markdown]
# ## Chauvenet

# %%
for col in outliercols:
    for c in [2, 4, 6, 8, 10, 100]:
        print(c)
        datasetch = OutlierDistr.chauvenet(dataset, col, c)
        DataViz.plot_binary_outliers(datasetch, col, col+"_outlier")
# Out:
# 2
# Figure saved to figures/figure_1.png
# 4
# Figure saved to figures/figure_2.png
# 6
# Figure saved to figures/figure_3.png
# 8
# Figure saved to figures/figure_4.png
# 10
# Figure saved to figures/figure_5.png
# 100
# Figure saved to figures/figure_6.png
# 2
# Figure saved to figures/figure_7.png
# 4
# Figure saved to figures/figure_8.png
# 6
# Figure saved to figures/figure_9.png
# 8
# Figure saved to figures/figure_10.png
# 10
# Figure saved to figures/figure_11.png
# 100
# Figure saved to figures/figure_12.png

# %% [markdown]
# ## Mixture

# %%
for col in outliercols:
    for comps, iters in [[3, 100], [6,200], [9, 300]]:
        print(comps, iters)
        datasetmix = OutlierDistr.mixture_model(dataset, col, comps, iters)
        DataViz.plot_dataset(datasetmix, [col, col+"_mixture"], ["exact", "exact"], ["line", "points"])
# Out:
# 3 100
# Applying mixture models
# Figure saved to figures/figure_13.png
# 6 200
# Applying mixture models
# Figure saved to figures/figure_14.png
# 9 300
# Applying mixture models
# Figure saved to figures/figure_15.png
# 3 100
# Applying mixture models
# Figure saved to figures/figure_16.png
# 6 200
# Applying mixture models
# Figure saved to figures/figure_17.png
# 9 300
# Applying mixture models
# Figure saved to figures/figure_18.png

# %% [markdown]
# ## Simple Distance

# %%
dmin = 0.10
fmin = 0.99
for col in outliercols:
    for dmin, fmin in [[0.10, 0.99], [0.12, 0.98], [0.15, 0.95]]:
        print(dmin, fmin)
        datasetdis = OutlierDist.simple_distance_based(dataset, [col], "euclidean", dmin, fmin)
        DataViz.plot_binary_outliers(datasetdis, col, 'simple_dist_outlier')
# Out:
# 0.1 0.99
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_19.png
# 0.12 0.98
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_20.png
# 0.15 0.95
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_21.png
# 0.1 0.99
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_22.png
# 0.12 0.98
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_23.png
# 0.15 0.95
# Calculating simple distance-based criterion.
# Figure saved to figures/figure_24.png

# %% [markdown]
# ## Local Outlier Factor

# %%
for col in outliercols:
    for K in [5, 10, 15]:
        print(K)
        datasetlof = OutlierDist.local_outlier_factor(copy.deepcopy(dataset), [col], "euclidean", K)
        DataViz.plot_dataset(datasetlof, [col, "lof"], ["exact", "exact"], ["line", "points"])
# Out:
# 5
# Calculating local outlier factor.
# Figure saved to figures/figure_25.png
# 10
# Calculating local outlier factor.
# Figure saved to figures/figure_26.png
# 15
# Calculating local outlier factor.
