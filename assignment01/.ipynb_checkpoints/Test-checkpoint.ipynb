# %%
from Chapter2.CreateDataset import CreateDataset
import pandas as pd
import matplotlib.pyplot as plt
import os
import copy
from util.VisualizeDataset import VisualizeDataset
from util import util

# %%
rawdatapath = "data/raw/"
outputpath = "data/intermediate/"
givenpath = "data/given/"

if not os.path.exists(outputpath):
    print("Empty path, so creating..." + outputpath + "...done!")
    os.makedirs(outputpath)

# %%
accraw = pd.read_csv(rawdatapath + "Accelerometer.csv")
timecol = "Time (s)"
accfeatures = list()
for col in accraw:
    if (col != timecol) and \
    (col != "Absolute acceleration (m/s^2)"):
        accfeatures.append(col)
accfeatures
# Out:
# ['Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)']

# %%
accraw
# Out:
#           Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0         0.018694               -1.977070                7.584650
# 1         0.021144               -2.020140                7.582257
# 2         0.023594               -2.003391                7.591828
# 3         0.026045               -2.008176                7.579864
# 4         0.028495               -1.993819                7.591828
# ...            ...                     ...                     ...
# 124856  300.012150               -2.254936                7.548757
# 124857  300.014552               -2.257329                7.560721
# 124858  300.016956               -2.235794                7.536793
# 124859  300.019358               -2.245365                7.541579
# 124860  300.021760               -2.259722                7.541579
#
#         Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                     6.073283                       9.915669
# 1                     6.054141                       9.910812
# 2                     6.054141                       9.914739
# 3                     6.056533                       9.908012
# 4                     6.020641                       9.892385
# ...                        ...                            ...
# 124856                5.733502                       9.743794
# 124857                5.735895                       9.755026
# 124858                5.757431                       9.744231
# 124859                5.764609                       9.754373
# 124860                5.769394                       9.760516
#
# [124861 rows x 5 columns]

# %%
accgiven = pd.read_csv(givenpath + "accelerometer_phone.csv")
timecol = "Time (s)"
accfeatures_given = list()
for col in accgiven:
    if (col != timecol) and \
    (col != "Absolute acceleration (m/s^2)"):
        accfeatures_given.append(col)
accfeatures_given
# Out:
# ['sensor_type', 'device_type', 'timestamps', 'x', 'y', 'z']

# %%
accgiven
# Out:
#            sensor_type device_type           timestamps      x      y      z
# 0        accelerometer  smartphone  1454956105656222395 -0.087  0.181  9.621
# 1        accelerometer  smartphone  1454956105660105781 -0.069  0.153  9.663
# 2        accelerometer  smartphone  1454956105667091406 -0.073  0.156  9.647
# 3        accelerometer  smartphone  1454956105670696615 -0.070  0.184  9.623
# 4        accelerometer  smartphone  1454956105675807552 -0.059  0.171  9.625
# ...                ...         ...                  ...    ...    ...    ...
# 1604601  accelerometer  smartphone  1454964064977354323 -0.166  0.178  9.628
# 1604602  accelerometer  smartphone  1454964064982928229 -0.174  0.183  9.643
# 1604603  accelerometer  smartphone  1454964064987681354 -0.174  0.183  9.643
# 1604604  accelerometer  smartphone  1454964064992564896 -0.154  0.177  9.666
# 1604605  accelerometer  smartphone  1454964064996744531 -0.159  0.203  9.629
#
# [1604606 rows x 6 columns]

# %%
acctime = pd.read_csv(rawdatapath + "Accelerometer_time.csv")
acctime
# Out:
#    event  experiment time   system time                   system time text
# 0  START         0.000000  1.622380e+09  2021-05-30 21:08:32.654 UTC+08:00
# 1  PAUSE       300.027308  1.622380e+09  2021-05-30 21:13:32.681 UTC+08:00

# %%
acctime["system time"][0]
# Out:
# 1622380112.654

# %%
accraw["Time (s)"] = accraw["Time (s)"] * 1e+9 + acctime["system time"][0] * 1e+9

# %%
accraw
# Out:
#             Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       1.622380e+18               -1.977070                7.584650
# 1       1.622380e+18               -2.020140                7.582257
# 2       1.622380e+18               -2.003391                7.591828
# 3       1.622380e+18               -2.008176                7.579864
# 4       1.622380e+18               -1.993819                7.591828
# ...              ...                     ...                     ...
# 124856  1.622380e+18               -2.254936                7.548757
# 124857  1.622380e+18               -2.257329                7.560721
# 124858  1.622380e+18               -2.235794                7.536793
# 124859  1.622380e+18               -2.245365                7.541579
# 124860  1.622380e+18               -2.259722                7.541579
#
#         Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                     6.073283                       9.915669
# 1                     6.054141                       9.910812
# 2                     6.054141                       9.914739
# 3                     6.056533                       9.908012
# 4                     6.020641                       9.892385
# ...                        ...                            ...
# 124856                5.733502                       9.743794
# 124857                5.735895                       9.755026
# 124858                5.757431                       9.744231
# 124859                5.764609                       9.754373
# 124860                5.769394                       9.760516
#
# [124861 rows x 5 columns]

# %%
accraw.to_csv("test.csv")

# %%
test = pd.read_csv(rawdatapath + "test.csv")
test
# Out:
#         Unnamed: 0      Time (s)  Acceleration x (m/s^2)  \
# 0                0  1.622380e+18               -1.977070
# 1                1  1.622380e+18               -2.020140
# 2                2  1.622380e+18               -2.003391
# 3                3  1.622380e+18               -2.008176
# 4                4  1.622380e+18               -1.993819
# ...            ...           ...                     ...
# 124856      124856  1.622380e+18               -2.254936
# 124857      124857  1.622380e+18               -2.257329
# 124858      124858  1.622380e+18               -2.235794
# 124859      124859  1.622380e+18               -2.245365
# 124860      124860  1.622380e+18               -2.259722
#
#         Acceleration y (m/s^2)  Acceleration z (m/s^2)  \
# 0                     7.584650                6.073283
# 1                     7.582257                6.054141
# 2                     7.591828                6.054141
# 3                     7.579864                6.056533
# 4                     7.591828                6.020641
# ...                        ...                     ...
# 124856                7.548757                5.733502
# 124857                7.560721                5.735895
# 124858                7.536793                5.757431
# 124859                7.541579                5.764609
# 124860                7.541579                5.769394
#
#         Absolute acceleration (m/s^2)
# 0                            9.915669
# 1                            9.910812
# 2                            9.914739
# 3                            9.908012
# 4                            9.892385
# ...                               ...
# 124856                       9.743794
# 124857                       9.755026
# 124858                       9.744231
# 124859                       9.754373
# 124860                       9.760516
#
# [124861 rows x 6 columns]

# %%
granularities = [60000, 250]
datasets = []

# %%
for g in granularities:
    Dataset = CreateDataset(rawdatapath, g)
    
    Dataset.add_numerical_dataset("test.csv", timecol, accfeatures, "avg", "acc_")
    
    dataset = Dataset.data_table
    print(dataset)
    Dataviz = VisualizeDataset()
    
    Dataviz.plot_dataset_boxplot(dataset, ['acc_Acceleration x (m/s^2)', 'acc_Acceleration y (m/s^2)', 'acc_Acceleration z (m/s^2)'])
# Out:
# Reading data from test.csv
#                               acc_Acceleration x (m/s^2)  \
# 2021-05-30 13:08:32.672693760                   -2.10048
# 2021-05-30 13:09:32.672693760                   -1.18907
# 2021-05-30 13:10:32.672693760                   -1.30737
# 2021-05-30 13:11:32.672693760                   -1.71858
# 2021-05-30 13:12:32.672693760                   -1.98216
# 2021-05-30 13:13:32.672693760                   -2.25254
#
#                               acc_Acceleration y (m/s^2)  \
# 2021-05-30 13:08:32.672693760                    7.30587
# 2021-05-30 13:09:32.672693760                    7.68569
# 2021-05-30 13:10:32.672693760                    7.32259
# 2021-05-30 13:11:32.672693760                    7.00316
# 2021-05-30 13:12:32.672693760                    7.46403
# 2021-05-30 13:13:32.672693760                    7.54158
#
#                               acc_Acceleration z (m/s^2)
# 2021-05-30 13:08:32.672693760                    6.15086
# 2021-05-30 13:09:32.672693760                    5.85465
# 2021-05-30 13:10:32.672693760                    6.22527
# 2021-05-30 13:11:32.672693760                    6.58447
# 2021-05-30 13:12:32.672693760                    5.96282
# 2021-05-30 13:13:32.672693760                      5.767
# Figure saved to figures/figure_1.png
# Reading data from test.csv
#                               acc_Acceleration x (m/s^2)  \
# 2021-05-30 13:08:32.672693760                   -2.01805
# 2021-05-30 13:08:32.922693760                   -2.01741
# 2021-05-30 13:08:33.172693760                   -2.02683
# 2021-05-30 13:08:33.422693760                   -2.04669
# 2021-05-30 13:08:33.672693760                   -2.02686
# ...                                                  ...
# 2021-05-30 13:13:31.672693760                   -2.30387
# 2021-05-30 13:13:31.922693760                   -2.30979
# 2021-05-30 13:13:32.172693760                   -2.29598
# 2021-05-30 13:13:32.422693760                   -2.27801
# 2021-05-30 13:13:32.672693760                   -2.25254
#
#                               acc_Acceleration y (m/s^2)  \
# 2021-05-30 13:08:32.672693760                    7.65542
# 2021-05-30 13:08:32.922693760                    7.66087
# 2021-05-30 13:08:33.172693760                    7.65699
# 2021-05-30 13:08:33.422693760                    7.64972
