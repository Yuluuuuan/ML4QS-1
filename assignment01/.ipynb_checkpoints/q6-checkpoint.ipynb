# %% [markdown]
# # CH04 - 4.5.2.2

# %%
from Chapter4.FrequencyAbstraction import FourierTransformation
from Chapter4.TemporalAbstraction import NumericalAbstraction
from util.VisualizeDataset import VisualizeDataset
import os
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
plt.rcParams["figure.figsize"] = [15,10]

# %%
rawdatapth = "data/result-given/"
outputpth = "data/intermediate/"

if not os.path.exists(outputpth):
    print("Empty path, so creating..." + outputpth + "...done!")
    os.makedirs(outputpth)

# %%
dataset = pd.read_csv(rawdatapth + "chapter3_result_final.csv", index_col=0)
dataset.index = pd.to_datetime(dataset.index)
dataset
# Out:
#                             acc_phone_x  acc_phone_y  acc_phone_z  \
# 2016-02-08 18:28:25.656222    -0.090433     0.164264     9.631744
# 2016-02-08 18:28:25.906222    -0.096204     0.168119     9.632371
# 2016-02-08 18:28:26.156222    -0.091631     0.166526     9.636167
# 2016-02-08 18:28:26.406222    -0.087132     0.167139     9.633979
# 2016-02-08 18:28:26.656222    -0.093228     0.166913     9.628586
# ...                                 ...          ...          ...
# 2016-02-08 20:41:03.906222    -0.162021     0.183981     9.610694
# 2016-02-08 20:41:04.156222    -0.162810     0.185584     9.611845
# 2016-02-08 20:41:04.406222    -0.160333     0.186314     9.614440
# 2016-02-08 20:41:04.656222    -0.158529     0.184669     9.614019
# 2016-02-08 20:41:04.906222    -0.164768     0.182617     9.623071
#
#                             acc_watch_x  acc_watch_y  acc_watch_z  \
# 2016-02-08 18:28:25.656222     9.550840     0.197679     1.513430
# ...

# %%
datafreq = copy.deepcopy(dataset)
datafreq
# Out:
#                             acc_phone_x  acc_phone_y  acc_phone_z  \
# 2016-02-08 18:28:25.656222    -0.090433     0.164264     9.631744
# 2016-02-08 18:28:25.906222    -0.096204     0.168119     9.632371
# 2016-02-08 18:28:26.156222    -0.091631     0.166526     9.636167
# 2016-02-08 18:28:26.406222    -0.087132     0.167139     9.633979
# 2016-02-08 18:28:26.656222    -0.093228     0.166913     9.628586
# ...                                 ...          ...          ...
# 2016-02-08 20:41:03.906222    -0.162021     0.183981     9.610694
# 2016-02-08 20:41:04.156222    -0.162810     0.185584     9.611845
# 2016-02-08 20:41:04.406222    -0.160333     0.186314     9.614440
# 2016-02-08 20:41:04.656222    -0.158529     0.184669     9.614019
# 2016-02-08 20:41:04.906222    -0.164768     0.182617     9.623071
#
#                             acc_watch_x  acc_watch_y  acc_watch_z  \
# 2016-02-08 18:28:25.656222     9.550840     0.197679     1.513430
# ...

# %%
NumAbs = NumericalAbstraction()
FreqAbs = FourierTransformation()
DataViz = VisualizeDataset()

# %%
ms = (dataset.index[1] - dataset.index[0]).microseconds/1000
ms
# Out:
# 250.0

# %%
ws = [int(float(5000)/ms), int(float(0.5*60000)/ms), int(float(5*60000)/ms)]
ws
# Out:
# [20, 120, 1200]

# %%
for w in ws:
    dataset = NumAbs.abstract_numerical(dataset, ['acc_phone_x'], w, 'sum')
    dataset = NumAbs.abstract_numerical(dataset, ['acc_phone_x'], w, 'cnt')
    dataset = NumAbs.abstract_numerical(dataset, ['acc_phone_x'], w, 'mean')

# %%
DataViz.plot_dataset(dataset,  ['acc_phone_x', 'acc_phone_x_temp_sum', 'acc_phone_x_temp_cnt','acc_phone_x_temp_mean', 'label'], ['exact', 'like', 'like', 'like', "like"], ['line', 'line', 'line',"line", 'points'])
# Out:
# Figure saved to figures\figure_1.png

# %%
fs = float(1000)/ms
fs
# Out:
# 4.0

# %%
datafreq = FreqAbs.abstract_frequency(dataset, ['acc_phone_x'], int(float(10000)/ms), fs)

# %%
DataViz.plot_dataset(dataset, ['acc_phone_x_max_freq', 'acc_phone_x_freq_weighted', 'acc_phone_x_pse', 'label'], ['like', 'like', 'like', 'like'], ['line', 'line', 'line','points'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-dad5af80efba> in <module>
# ----> 1 DataViz.plot_dataset(datafreq, ['acc_phone_x_skewness', 'label'], ['like', 'like'], ['line', 'points'])
#
# ~\OneDrive\VU-Cources\Machine-Learning-for-the-Quantified-Self\assignments\ML4QS\assignment01\util\VisualizeDataset.py in plot_dataset(self, data_table, columns, match, display)
#     103                           bbox_to_anchor=(0.5, 1.3), ncol=len(relevant_cols), fancybox=True, shadow=True)
#     104
# --> 105             xar[i].set_ylim([min(min_values) - 0.1*(max(max_values) - min(min_values)),
#     106                              max(max_values) + 0.1*(max(max_values) - min(min_values))])
#     107
#
# ValueError: min() arg is an empty sequence
